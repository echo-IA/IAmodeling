# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
sys.path.append('./')
from A_IA_plots import *

# %%
mpl.rcParams['font.size'] = 16
mpl.rcParams['text.usetex'] = 'True'
mpl.rcParams['axes.labelsize'] = 'large'

# %%
fig, ax = plot_A_IA("logMh", "A_IA")

# %%
def A_IA_L(L, A0, beta):
    return A0 * L**beta

A0 = 5.95
A0_err = 0.49

beta = 0.68
beta_err = 0.18

A0_beta_covariance = -0.00679221

# %%
LoverL0 = np.linspace(0.05, 4, 32)
ax.plot(np.log10(LoverL0), A_IA_L(LoverL0, A0, beta), color='xkcd:vermillion')

y = A_IA_L(LoverL0, A0, beta)
dfdA = y/A0
dfdb = beta*y
A_IA_L_err = np.sqrt((dfdA**2*A0_err**2)+
                     (dfdb**2*beta_err**2) + 
                     2*dfdA*dfdb*A0_beta_covariance)

ax.fill_between(np.log10(LoverL0),
                y+A_IA_L_err,
                y-A_IA_L_err,
                alpha=0.1, color='xkcd:vermillion')

# %%
fig.show()
# Out:
# /var/folders/1t/x_jrxgpx0nqbzf9ffsvvm6yh0000gn/T/ipykernel_67757/89474557.py:1: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
